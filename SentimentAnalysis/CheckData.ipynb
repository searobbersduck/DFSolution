# %%
# /usr/bin/env python3
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_train = pd.read_csv('./data/Test_DataSet.csv')

# %%
# df_train[df_train['label']==0].head(50)

# %%
# df_train[df_train['label']==1].head(50)

# %%
# df_train[df_train['label']==2].head(50)

# %%
# df_0 = df_train[df_train['label']==0]
# df_1 = df_train[df_train['label']==1]
# df_2 = df_train[df_train['label']==2]

# %%
# for index,row in df_0.iterrows():
#     print('title:\t{}'.format(row['title']))
#     print('content:\t{}'.format(row['content']))
#     print('\n')

# %%
# for index,row in df_1.iterrows():
#     print('title:\t{}'.format(row['title']))
#     print('content:\t{}'.format(row['content']))
#     print('\n')

# %%
# for index,row in df_2.iterrows():
#     print('title:\t{}'.format(row['title']))
#     print('content:\t{}'.format(row['content']))
#     print('\n')

# %%
df_title_len = df_train['title'].apply(lambda x:len(x) if type(x) is not float else x)
(df_title_len < 10).value_counts()
df_train[df_title_len < 10]
# Out:
#                                     id      title  \
# 41    01458ff5d3704ace8c4fd5b4716cbfcf      自拔亦痛哭
# 46    017e91d75654466e8d471653f84b1c79      库房出售！
# 50    01a4a1b49b334171abfe6fa776e5e32a  小米米兔无人机评测
# 54    01c45e1e15b94dbeaefd915bd6c8fc22    真真的，来品鉴
# 102   0346601976574857b137c8ab05d91cfb   奔着结婚去的?嘛
# 138   049920d6385f4dcf9f5dadc3abad2cbb      大河客户端
# 160   057d9cb08b184f41bd931597f429a599    一起游泳吗来吗
# 166   05cc31ed60df4a06ab2c62079aa27550       注册不了
# 186   068c1c456a50497d8224276ef30ae08f  三五知己，谈笑风生
# 204   0714a4463f344a3aa4464fb0359d4976     共享经济时代
# 230   08291bdc2d8842fa9c6394e674e793c6  镇江北固楼上观长江
# 237   0888622b4ba34c019589a1c10bd509db       独院出租
# 314   0b1d87ebb01a447097a0d3034430292d  上方山，，还要门票
# 357   0c8ad544a9114152ac39ec86b359d263   阳畦高速公路大队
# 378   0d2f9a0d5c3942fe8d2e69c6ce6d3e0a     南乐去衡水啦
# 382   0d4c42135a90411b948b6b0eb2bf9838      手机开机慢
# 387   0d8c00a9081f4051a8ce7ab7cf2ff90f        来人啊
# 388   0d8ed2417c974b5d8db365d51ef43df8     最高人民法院
# 396   0de0e9f7632647c4a267e5d667efb4a4    篮球必发指数网
# 411   0e70e827180746a3b7f63fc1c2986468    中国气象爱好者
# 454   1060bd198b694785b5161d6ea7cbd394      同江女上門
# 464   10a2d1ff773b4b21b4d92c0ad330857b      进来吃宵夜
# 470   10f9b790a2274fa0aa1c85f5f472ff2f       公  示
# 503   1227d2dce1624384a608fe90d9abe64a    高仿名牌包批发
# 539   130f82c1bad04cafbe6ea7ef8ec1a88c  靓女改运的神奇秘法
# 556   138be9a3260e4f91b09c2b753b4b8cef   西安西郊劳务纠纷
# 573   14350e88491d4436afd030957a11ab3e    5月行情可期！
# 599   152492fd8e3c4df18a37757446673dd4  利辛夜宵有约的没？
# 620   15c72ad8c00143d88704d118ec641c75       分享视频
# 645   16b51f8ea9ca471686c7108d12120f38      红梅小姐4
# ...                                ...        ...
# 6580  e4bf236e3c944c118061d11db9ba070b   这地是停车场？？
# 6614  e5c4815b58ab46a5a74efb4ba19f466d  男子精通制造假邮票
# 6687  e8a49355d15b43ec98e4ada7b7516750  微笑不露声色的张扬
# 6730  e9f8438280424a0faf1099bae74648e6        感谢信
# 6764  eb019a00a65c40a28bcd54d81add0775  重庆皮肤病医院专科
# 6791  ebe6b1270f5c418c88ef124d6061bc80     #NAME?
